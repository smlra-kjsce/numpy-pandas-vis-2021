# %% [markdown]
# <a href="https://colab.research.google.com/github/smlra-kjsce/numpy-pandas-vis-2021/blob/main/DataViz/DataViz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EDA
#
# -  is all about asking questions to make conclusions on the data
# - This is done to understand the dataset and make better decisions for the choice of algorithm/architecture
#
#
# To carry on that mindset, in this session we will be using the

# %% [markdown]
# ## HYW approach
#
# **H** -> How does it work -> Math and intuition behind it
#
# **Y** -> Why to use it -> what it achieves
#
# **W** -> Where to use it -> use in real world case

# %% [markdown]
# # Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
planet = sns.load_dataset("planets")
flights = sns.load_dataset("flights")

# %%
flights.head(10)

# %% [markdown]
# # Uni vs Bi vs Multi variate

# %% [markdown]
# Univariate --> One dependent variable
#
# Bivariate --> Relation between two variable
#
# Multivariate --> more than 2 variable analysis

# %% [markdown]
# ## Line plots

# %%
len(planet)
# Out:
# 1035

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [895, 910, 919, 926, 929, 931]

# %%
plt.plot(years, yield_apples)

# %%
sns.lineplot(data=flights, x="year", y="passengers", hue="month")

# %% [markdown]
# ## Scatter plots

# %%
plt.plot(planet.mass, planet.distance)

# %%
sns.scatterplot(x='mass', y = 'distance', hue = "number", s = 100 , data = planet)

# %% [markdown]
# ##Confidence Intervals

# %% [markdown]
# - A confidence interval displays the probability that a parameter will fall between a pair of values around the mean.
# - Confidence intervals measure the degree of uncertainty or certainty in a sampling method.
# - They are most often constructed using confidence levels of 95% or 99%.
# - Statisticians use confidence intervals to measure uncertainty in a sample variable.

# %% [markdown]
# Data: Height of basketball players
#
# Assume the 95% confidence interval is between 72 inches and 76 inches.
#
# If the researchers take 100 random samples from the population of high school basketball players as a whole, the mean should fall between 72 and 76 inches in 95 of those samples.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![](https://nulib.github.io/moderndive_book/ismaykimkuyper_files/figure-html/N-CIs-1.png)

# %%
sns.lineplot(data=flights, x="year", y="passengers")

# %%
sns.scatterplot(data=flights, x="year", y="passengers")

# %% [markdown]
# ## Percentile

# %% [markdown]
# The sample 100p percentile is that data value such that 100p percent of the data are less
# than or equal to it and 100(1−p) percent are greater than or equal to it. If two data values
# satisfy this condition, then the sample 100p percentile is the arithmetic average of these
# two values.
#
# To determine the sample 100p percentile of a data set of size n, we need to determine
# the data values such that
# 1. At least np of the values are less than or equal to it.
# 2. At least n(1−p) of the values are greater than or equal to it.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sample size  = 25
#
# Here,
# (25)*0.10 = 2.5
#
# Sample 10 percentile is Third smallest value --> 590763
#
# Because 25(.80)=20, the sample 80 percentile is the average of the twentieth and
# the twenty-first smallest values.

# %% [markdown]
# ## Boxplots

# %% [markdown]
# ![](https://miro.medium.com/max/875/1*NRlqiZGQdsIyAu0KzP7LaQ.png)

# %% [markdown]
# Why -->
# 1. Median
# 2. Interquatile Range
# 3. Lower and Upper Adjacent values for simple detection of outliers

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
tips = sns.load_dataset("tips")
ax = sns.boxplot(x=tips["total_bill"])

# %%
ax = sns.boxplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.boxplot(x="day", y="total_bill", hue="smoker", 
                 data=tips, palette="Set2")

# %% [markdown]
# ## Histograms

# %% [markdown]
# Dividing the data range into intervals

# %%
flowers_df = sns.load_dataset("iris")
flowers_df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df.sepal_width); #control number of bins

# %% [markdown]
# Please observe that the height of the bars is only useful when combined with the base width. That is, we cannot read off probabilities directly from the y-axis; probabilities are accessed only as areas under the curve. This is true not only for histograms but for all density functions.

# %% [markdown]
# ## KDE

# %% [markdown]
# - We are trying to guess the density function f that describes well the randomness of the data.
# - But histograms are too rigid, stacks of rectangles
# - To calculate a smoother, real world estimate --> Kernel Distribution Estimation
# - rather than rectangles, uses "stack of sand function"
#
# ![](https://miro.medium.com/max/875/1*VcriO31VYV6EeyJqHjbLyg.png)
#
# ![](https://miro.medium.com/max/360/1*V-Q5HCAboPqfTIs6gZT4vg.png)
#
# "Stickiness" of the sand determines the overall height
#
# ![](https://miro.medium.com/max/295/1*jiQb55lhYRss0C4qyvW8_w.png)
# Where h represents bandwidth
#
#
# -- Combining multitude of these sandpiles, we can create a smooth distribution estimation
#
# - This is especially helpful in multimodal data --> data with mutliple peaks

# %%
iris = sns.load_dataset("iris")
sns.kdeplot(data=iris) #bw adjusting

# %% [markdown]
# ## Violin plots

# %% [markdown]
# Violin plots are a combination of box plots and KDE.
#
# ![](https://miro.medium.com/max/650/1*TTMOaNG1o4PgQd-e8LurMg.png)

# %%
def plot_comparison(x, title):
    fig, ax = plt.subplots(3, 1, sharex=True)
    sns.distplot(x, ax=ax[0])
    ax[0].set_title('Histogram + KDE')
    sns.boxplot(x, ax=ax[1])
    ax[1].set_title('Boxplot')
    sns.violinplot(x, ax=ax[2])
    ax[2].set_title('Violin plot')
    fig.suptitle(title, fontsize=16)
    plt.show()
N = 10 ** 4

# %%
# Standard normal distribution
sample_gaussian = np.random.normal(size=N)
plot_comparison(sample_gaussian, 'Standard Normal Distribution')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Log normal distribution
sample_lognormal = np.random.lognormal(size=N)
plot_comparison(sample_lognormal, 'Log-normal Distribution')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
bx = sns.violinplot(x=tips["total_bill"])

# %%
ax = sns.violinplot(x="day", y="total_bill", hue="smoker",
                    data=tips, palette="muted", split=True)

# %% [markdown]
# ## Heatmaps

# %%
flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")

# %%
sns.heatmap(flights_df);

# %% [markdown]
# ## Catplots

# %% [markdown]
# Combining box plots with facetgrids

# %%
g = sns.catplot(x="sex", y="total_bill",
                hue="smoker", col="time",
                data=tips, kind="box",
                height=4, aspect=.7);

# %% [markdown]
# ## Grids

# %%
g = sns.FacetGrid(tips, col="sex", hue="smoker")
g.map(sns.scatterplot, "total_bill", "tip", alpha=.7)
g.add_legend()

# %%
ordered_days = tips.day.value_counts().index
g = sns.FacetGrid(tips, row="day", row_order=ordered_days,
                  height=1.7, aspect=4,)
g.map(sns.kdeplot, "total_bill")

# %% [markdown]
# # Homework

# %% [markdown]
# Try to summarize the datasets provided by seaborn
#
# That includes:
#
# - Understanding the distributions of important columns
# - graphing the relationship
# - Conclusions about each dataset
#
# For starters, pick up "tips" dataset and use all the commands you have learned to visualize many different relationships at the same time!

# %% [markdown]
# # References

# %% [markdown]
# ### Datasets to work with:
#
# - https://archive.ics.uci.edu/ml/datasets/Carbon+Nanotubes
#
# - https://www.kaggle.com/omermetinn/tweets-about-the-top-companies-from-2015-to-2020

# %% [markdown]
# ### Library documentations
# - https://seaborn.pydata.org/tutorial.html
#
# - https://matplotlib.org/stable/tutorials/index.html

# %% [markdown]
# ### Excellent book for statistics and data science
#
# - "Probability and Statistics for Engineers" and Scientists by Sheldon Ross

# %% [markdown]
# ### Extra
#
# - https://www.analyticsvidhya.com/blog/2021/04/exploratory-analysis-using-univariate-bivariate-and-multivariate-analysis-techniques/
#
# - https://www.kaggle.com/residentmario/multivariate-plotting
#
# - https://towardsdatascience.com/histograms-vs-kdes-explained-ed62e7753f12
